# %% [markdown]
# Applied to make data normal
# <br><br>
# How to know if normal or skewed?<br>
# - sns.distplot
# - pd.skew
# - qqplot

# %% [markdown]
# Log Transform on RIGHT SKEWED <br>
# (linear and logistic regression happy)<br><br>

# %% [markdown]
# Reciprocal: <br>
# Square: LEFT SKEWED<br>
# squareroot:<br><br>

# %% [markdown]
# Btw run everything you never know what's better

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
from sklearn.model_selection import train_test_split
