# %% [markdown]
# Feature Engineering: <br><br>
# Transformation<br>
# -> Taking care of missing values <br>
# -> Categorical values: Encoding to covert it numerical <br>
# -> Outliner detection <br>
# -> Feature Scaling <br><br>
# Construction<br><br>
# Selection<br><br>
# Extraction<br><br>
